# %% [markdown]
# ## Python Libraries:
#                     - BeautifulSoup
#
#                     - Django
#
#                     - Flask
#
#                     - Matplotlib
#
#                     - NumPy - DONE
#
#                     - Pandas - DONE
#
#                     - PyTorch
#
#                     - Requests
#
#                     - Scikit-learn
#
#                     - TensorFlow
