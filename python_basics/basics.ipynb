# %% [markdown]
# ## Python Libraries:
#                     - BeautifulSoup
#
#                     - Django
#
#                     - Flask
#
#                     - Matplotlib
#
#                     - NumPy
#
#                     - Pandas
#
#                     - PyTorch
#
#                     - Requests
#
#                     - Scikit-learn
#
#                     - TensorFlow
